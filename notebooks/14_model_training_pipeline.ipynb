# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
import src.config as config

# %%
import hopsworks

project = hopsworks.login(
    project=config.HOPSWORKS_PROJECT_NAME, api_key_value=config.HOPSWORKS_API_KEY
)

feature_store = project.get_feature_store()
feature_group = feature_store.get_feature_group(
    name=config.FEATURE_GROUP_NAME,
    version=config.FEATURE_GROUP_VERSION
)
# Out:
# 2025-03-03 15:13:35,394 INFO: Initializing external client
# 2025-03-03 15:13:35,395 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-03-03 15:13:36,843 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1213633

# %%
# Create a feature view if it doesn't already exist
try:
    feature_store.create_feature_view(
        name=config.FEATURE_VIEW_NAME,
        version=config.FEATURE_VIEW_VERSION,
        query=feature_group.select_all(),
    )
    print(f"Feature view '{config.FEATURE_VIEW_NAME}' (version {config.FEATURE_VIEW_VERSION}) created successfully.")
except Exception as e:
    print(f"Error creating feature view: {e}")

# Retrieve the feature view
try:
    feature_view = feature_store.get_feature_view(
        name=config.FEATURE_VIEW_NAME,
        version=config.FEATURE_VIEW_VERSION,
    )
    print(f"Feature view '{config.FEATURE_VIEW_NAME}' (version {config.FEATURE_VIEW_VERSION}) retrieved successfully.")
except Exception as e:
    print(f"Error retrieving feature view: {e}")
# Out:
# Error creating feature view: Metadata operation error: (url: https://c.app.hopsworks.ai/hopsworks-api/api/project/1213633/featurestores/1201258/featureview). Server response:
# HTTP code: 400, HTTP reason: Bad Request, body: b'{"errorCode":270179,"usrMsg":"Feature view: time_series_hourly_feature_view, version: 1","errorMsg":"The provided feature view name and version already exists"}', error code: 270179, error msg: The provided feature view name and version already exists, user msg: Feature view: time_series_hourly_feature_view, version: 1
# Feature view 'time_series_hourly_feature_view' (version 1) retrieved successfully.

# %%
ts_data, _ = feature_view.training_data(
    description="Time-series hourly taxi rides"
)
# Out:
# 2025-03-03 15:14:35,317 ERROR: Flight returned timeout error, with message: Deadline Exceeded
# Traceback (most recent call last):
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py", line 209, in __init__
#     self._health_check()
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 56, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 266, in call
#     raise attempt.get()
#           ^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 301, in get
#     six.reraise(self.value[0], self.value[1], self.value[2])
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\six.py", line 724, in reraise
#     raise value
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 251, in call
#     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#                       ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py", line 307, in _health_check
#     list(self._connection.do_action(action, options=options))
#   File "pyarrow\\_flight.pyx", line 1556, in _do_action_response
#   File "pyarrow\\_flight.pyx", line 60, in pyarrow._flight.check_flight_status
# pyarrow._flight.FlightTimedOutError: Flight returned timeout error, with message: Deadline Exceeded
# UserWarning: Failed to connect to Hopsworks Query Service, got Flight returned timeout error, with message: Deadline Exceeded.Defaulting to Spark execution for this call.The client will remain active for future calls. If the issue persists write_options={"use_spark": True}.
# 2025-03-03 15:14:42,103 ERROR: Flight returned timeout error, with message: Deadline Exceeded
# Traceback (most recent call last):
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py", line 394, in afs_error_handler_wrapper
#     return func(instance, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py", line 459, in read_query
#     return self._get_dataset(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 56, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 257, in call
#     return attempt.get(self._wrap_exception)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 301, in get
#     six.reraise(self.value[0], self.value[1], self.value[2])
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\six.py", line 724, in reraise
#     raise value
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 251, in call
#     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#                       ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py", line 440, in _get_dataset
#     info = self.get_flight_info(descriptor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 56, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 257, in call
#     return attempt.get(self._wrap_exception)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 301, in get
#     six.reraise(self.value[0], self.value[1], self.value[2])
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\six.py", line 724, in reraise
#     raise value
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py", line 251, in call
#     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#                       ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py", line 427, in get_flight_info
#     return self._connection.get_flight_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pyarrow\\_flight.pyx", line 1600, in pyarrow._flight.FlightClient.get_flight_info
#   File "pyarrow\\_flight.pyx", line 60, in pyarrow._flight.check_flight_status
# pyarrow._flight.FlightTimedOutError: Flight returned timeout error, with message: Deadline Exceeded
# Error: Reading data from Hopsworks, using Hopsworks Feature Query Service
# ---------------------------------------------------------------------------
# FlightTimedOutError                       Traceback (most recent call last)
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py:394, in ArrowFlightClient._handle_afs_exception.<locals>.decorator.<locals>.afs_error_handler_wrapper(instance, *args, **kw)
#     393 try:
# --> 394     return func(instance, *args, **kw)
#     395 except Exception as e:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py:459, in ArrowFlightClient.read_query(self, query_object, arrow_flight_config, dataframe_type)
#     458 descriptor = pyarrow.flight.FlightDescriptor.for_command(query_encoded)
# --> 459 return self._get_dataset(
#     460     descriptor,
#     461     (
#     462         arrow_flight_config.get("timeout", self.timeout)
#     463         if arrow_flight_config
#     464         else self.timeout
#     465     ),
#     466     dataframe_type,
#     467 )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:257, in Retrying.call(self, fn, *args, **kwargs)
#     256 if not self.should_reject(attempt):
# --> 257     return attempt.get(self._wrap_exception)
#     259 if self._after_attempts:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\six.py:724, in reraise(tp, value, tb)
#     723         raise value.with_traceback(tb)
# --> 724     raise value
#     725 finally:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py:440, in ArrowFlightClient._get_dataset(self, descriptor, timeout, dataframe_type)
#     439     timeout = self.timeout
# --> 440 info = self.get_flight_info(descriptor)
#     441 _logger.debug("Retrieved flight info: %s. Fetching dataset.", str(info))
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:257, in Retrying.call(self, fn, *args, **kwargs)
#     256 if not self.should_reject(attempt):
# --> 257     return attempt.get(self._wrap_exception)
#     259 if self._after_attempts:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\six.py:724, in reraise(tp, value, tb)
#     723         raise value.with_traceback(tb)
# --> 724     raise value
#     725 finally:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py:427, in ArrowFlightClient.get_flight_info(self, descriptor)
#     426 options = pyarrow.flight.FlightCallOptions(timeout=self.health_check_timeout)
# --> 427 return self._connection.get_flight_info(
#     428     descriptor,
#     429     options=options,
#     430 )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\pyarrow\_flight.pyx:1600, in pyarrow._flight.FlightClient.get_flight_info()
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\pyarrow\_flight.pyx:60, in pyarrow._flight.check_flight_status()
#
# FlightTimedOutError: Flight returned timeout error, with message: Deadline Exceeded
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ts_data, _ = feature_view.training_data(
#       2     description="Time-series hourly taxi rides"
#       3 )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hopsworks_common\usage.py:246, in method_logger.<locals>.wrapper(*args, **kwargs)
#     244 except Exception as e:
#     245     exception = e
# --> 246     raise e
#     247 finally:
#     248     try:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hopsworks_common\usage.py:242, in method_logger.<locals>.wrapper(*args, **kwargs)
#     239 exception = None
#     240 try:
#     241     # Call the original method
# --> 242     result = func(*args, **kwargs)
#     243     return result
#     244 except Exception as e:
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\feature_view.py:2299, in FeatureView.training_data(self, start_time, end_time, description, extra_filter, statistics_config, read_options, spine, primary_key, event_time, training_helper_columns, dataframe_type, transformation_context, **kwargs)
#    2186 """
#    2187 Create the metadata for a training dataset and get the corresponding training data from the offline feature store.
#    2188 This returns the training data in memory and does not materialise data in storage.
#    (...)
#    2282     (X, y): Tuple of dataframe of features and labels. If there are no labels, y returns `None`.
#    2283 """
#    2284 td = training_dataset.TrainingDataset(
#    2285     name=self.name,
#    2286     version=None,
#    (...)
#    2297     extra_filter=extra_filter,
#    2298 )
# -> 2299 td, df = self._feature_view_engine.get_training_data(
#    2300     self,
#    2301     read_options,
#    2302     training_dataset_obj=td,
#    2303     spine=spine,
#    2304     primary_keys=kwargs.get("primary_keys") or primary_key,
#    2305     event_time=event_time,
#    2306     training_helper_columns=training_helper_columns,
#    2307     dataframe_type=dataframe_type,
#    2308     transformation_context=transformation_context,
#    2309 )
#    2310 warnings.warn(
#    2311     "Incremented version to `{}`.".format(td.version),
#    2312     util.VersionWarning,
#    2313     stacklevel=1,
#    2314 )
#    2315 self.update_last_accessed_training_dataset(td.version)
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\feature_view_engine.py:496, in FeatureViewEngine.get_training_data(self, feature_view_obj, read_options, splits, training_dataset_obj, training_dataset_version, spine, primary_keys, event_time, training_helper_columns, dataframe_type, transformation_context)
#     483     self._check_feature_group_accessibility(feature_view_obj)
#     484     query = self.get_batch_query(
#     485         feature_view_obj,
#     486         training_dataset_version=td_updated.version,
#    (...)
#     494         spine=spine,
#     495     )
# --> 496     split_df = engine.get_instance().get_training_data(
#     497         td_updated,
#     498         feature_view_obj,
#     499         query,
#     500         read_options,
#     501         dataframe_type,
#     502         training_dataset_version,
#     503         transformation_context=transformation_context,
#     504     )
#     505     self.compute_training_dataset_statistics(
#     506         feature_view_obj, td_updated, split_df
#     507     )
#     509 # Getting transformed label names
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\engine\python.py:906, in Engine.get_training_data(self, training_dataset_obj, feature_view_obj, query_obj, read_options, dataframe_type, training_dataset_version, transformation_context)
#     896     return self._prepare_transform_split_df(
#     897         query_obj,
#     898         training_dataset_obj,
#    (...)
#     903         transformation_context=transformation_context,
#     904     )
#     905 else:
# --> 906     df = query_obj.read(
#     907         read_options=read_options, dataframe_type=dataframe_type
#     908     )
#     909     # if training_dataset_version is None:
#     910     transformation_function_engine.TransformationFunctionEngine.compute_and_set_feature_statistics(
#     911         training_dataset_obj, feature_view_obj, df
#     912     )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\constructor\query.py:206, in Query.read(self, online, dataframe_type, read_options)
#     201     if len(self.joins) > 0 or None in [f.type for f in schema]:
#     202         raise ValueError(
#     203             "Pandas types casting only supported for feature_group.read()/query.select_all()"
#     204         )
# --> 206 return engine.get_instance().sql(
#     207     sql_query,
#     208     self._feature_store_name,
#     209     online_conn,
#     210     dataframe_type,
#     211     read_options,
#     212     schema,
#     213 )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\engine\python.py:146, in Engine.sql(self, sql_query, feature_store, online_conn, dataframe_type, read_options, schema)
#     136 def sql(
#     137     self,
#     138     sql_query: str,
#    (...)
#     143     schema: Optional[List[feature.Feature]] = None,
#     144 ) -> Union[pd.DataFrame, pl.DataFrame]:
#     145     if not online_conn:
# --> 146         return self._sql_offline(
#     147             sql_query,
#     148             dataframe_type,
#     149             schema,
#     150             arrow_flight_config=read_options.get("arrow_flight_config", {})
#     151             if read_options
#     152             else {},
#     153         )
#     154     else:
#     155         return self._jdbc(
#     156             sql_query, online_conn, dataframe_type, read_options, schema
#     157         )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\engine\python.py:189, in Engine._sql_offline(self, sql_query, dataframe_type, schema, arrow_flight_config)
#     186 if isinstance(sql_query, dict) and "query_string" in sql_query:
#     187     from hsfs.core import arrow_flight_client
# --> 189     result_df = util.run_with_loading_animation(
#     190         "Reading data from Hopsworks, using Hopsworks Feature Query Service",
#     191         arrow_flight_client.get_instance().read_query,
#     192         sql_query,
#     193         arrow_flight_config or {},
#     194         dataframe_type,
#     195     )
#     196 else:
#     197     raise ValueError(
#     198         "Reading data with Hive is not supported when using hopsworks client version >= 4.0"
#     199     )
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hopsworks_common\util.py:303, in run_with_loading_animation(message, func, *args, **kwargs)
#     300 end = None
#     302 try:
# --> 303     result = func(*args, **kwargs)
#     304     end = time.time()
#     305     return result
#
# File ~\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\hsfs\core\arrow_flight_client.py:399, in ArrowFlightClient._handle_afs_exception.<locals>.decorator.<locals>.afs_error_handler_wrapper(instance, *args, **kw)
#     397 _logger.debug("Caught exception in %s: %s", func.__name__, message)
#     398 _logger.exception(e)
# --> 399 if instance._server_version is None and (
#     400     isinstance(e, FlightServerError)
#     401     and "Please register client certificates first." in message
#     402 ):
#     403     instance._register_certificates()
#     404     return func(instance, *args, **kw)
#
# AttributeError: 'ArrowFlightClient' object has no attribute '_server_version'

# %%
ts_data = ts_data.sort_values(["pickup_location_id", "pickup_hour"]).reset_index(drop=True)

# %%
ts_data.head()

# %%
ts_data["pickup_hour"].min()

# %%
ts_data["pickup_hour"].max()

# %%
ts_data_copy = ts_data.copy()

# %%
import pandas as pd
ts_data["pickup_hour"] = pd.to_datetime(ts_data["pickup_hour"], errors="coerce")

# %%
ts_data.info()

# %%
ts_data["pickup_hour"] = ts_data["pickup_hour"].dt.tz_localize(None)  # Remove timezone

# %%
ts_data.info()

# %%
ts_data["year_month"] = ts_data["pickup_hour"].dt.to_period("M")  # Year-Month format

# %%
ts_data

# %%
import matplotlib.pyplot as plt

# Group by year_month and count
hour_counts = ts_data.groupby("year_month").size()

# Plot the data
ax = hour_counts.plot(kind="bar", figsize=(10, 6), color="skyblue", edgecolor="black")  # Use 'ax' to store the plot object
ax.set_title("Number of Hours by Year/Month", fontsize=16)
ax.set_xlabel("Year-Month", fontsize=12)
ax.set_ylabel("Count of Hours", fontsize=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
ts_data.head()

# %%
gte = ts_data["year_month"] >= pd.Period("2023-01", freq="M")
lte = ts_data["year_month"] <= pd.Period("2023-12", freq="M")
cond = gte & lte
filtered_data = ts_data[cond].reset_index(drop=True)

# %%
filtered_data.drop(columns=["year_month"], inplace=True)

# %%
filtered_data.shape

# %%
ts_data = filtered_data

# %%
ts_data.info()

# %%
ts_data.head()["pickup_hour"].values

# %%
from src.data_utils import transform_ts_data_info_features_and_target

features, targets = transform_ts_data_info_features_and_target(ts_data, window_size=24*28, step_size=23)

# %%
features.sort_values(["pickup_location_id", "pickup_hour"])

# %%
features[features["pickup_location_id"] == 2]

# %%
features_copy = features.copy()

# %%
features_targets = features.copy()
features_targets["target"] = targets

features_targets.shape

# %%
from datetime import datetime, timedelta  
import pandas as pd  
from src.data_utils import split_time_series_data  

# Define the cutoff date as 28 days before today  
cutoff_date = pd.Timestamp(datetime.now() - timedelta(days=28))  
# # Convert the cutoff date to a string in a specific format (e.g., 'YYYY-MM-DD')  
# cutoff_date_str = cutoff_date.strftime('%Y-%m-%d')
# # Print the string representation of the cutoff date  
# print(f"Cutoff date as string: {cutoff_date_str}")
cutoff_date

# %%
X_train, y_train, X_test, y_test = split_time_series_data(
    features_targets,
    cutoff_date=cutoff_date,
    target_column="target"
)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %%
X_train.info()

# %%
from src.pipeline_utils import get_pipeline
pipeline = get_pipeline()

# %%
pipeline.fit(features, targets)

# %%
from sklearn.metrics import mean_absolute_error
predictions = pipeline.predict(features)

# %%
predictions

# %%
test_mae = mean_absolute_error(targets, predictions)
print(f"{test_mae:.4f}")

# %%
import joblib  


# Save the pipeline  
joblib.dump(pipeline, config.MODELS_DIR / "lgb_model.pkl")

# %%
from hsml.schema import Schema
from hsml.model_schema import ModelSchema

input_schema = Schema(features)
output_schema = Schema(targets)
model_schema = ModelSchema(input_schema=input_schema, output_schema=output_schema)

# %%
model_registry = project.get_model_registry()

model = model_registry.sklearn.create_model(
    name="taxi_demand_predictor_next_hour",
    metrics={"test_mae": test_mae},
    description="LightGBM regressor",
    input_example=features.sample(),
    model_schema=model_schema,
    #include_files=["src/", "requirements.txt"]  # Include directories and files
)
# https://community.hopsworks.ai/t/attributeerror-windowspath-object-has-no-attribute-startswith/1003
# model.save(config.MODELS_DIR / 'lgb_model.pkl')
model.save('C:\\Users\\vasub\\Desktop\\UB Learn\\Spring_2025\\Applied_ML\\Projects\\sp25_taxi-main\\models\\lgb_model.pkl')

# %%
from src.inference import load_model_from_registry

model = load_model_from_registry()

# %%
from src.inference import get_model_predictions

# %%
preds = get_model_predictions(model, features_copy)

# %%
#model.get_m

# %%
preds

# %%
test_mae = mean_absolute_error(targets, preds["predicted_demand"])
print(f"{test_mae:.4f}")

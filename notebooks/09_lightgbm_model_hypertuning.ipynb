# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import pandas as pd
from src.config import TRANSFORMED_DATA_DIR

df = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")

# %%
from datetime import datetime

from src.data_utils import split_time_series_data

X_train, y_train, X_test, y_test = split_time_series_data(
    df,
    cutoff_date=datetime(2023, 9, 1, 0, 0, 0),
    target_column="target"
)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (55900, 674)
# (55900,)
# (31720, 674)
# (31720,)

# %%
past_ride_columns = [c for c in X_train.columns if c.startswith("rides_")]
X_train_only_numeric = X_train[past_ride_columns]
X_test_only_numeric = X_test[past_ride_columns]

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\vasub\anaconda3\envs\sp25_taxi_ipt\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vasub\anaconda3\envs\sp25_taxi_ipt\lib\site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in c:\users\vasub\anaconda3\envs\sp25_taxi_ipt\lib\site-packages (from lightgbm) (1.15.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb
model = lgb.LGBMRegressor()
model.fit(X_train_only_numeric, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.306017 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 159651
# [LightGBM] [Info] Number of data points in the train set: 55900, number of used features: 672
# [LightGBM] [Info] Start training from score 11.110286
# LGBMRegressor()

# %%
from sklearn.metrics import mean_absolute_error
predictions = model.predict(X_test_only_numeric)

# %%
test_mae = mean_absolute_error(y_test, predictions)
print(f"{test_mae:.4f}")
# Out:
# 3.3054

# %%
import mlflow
import dagshub

# Initialize DagsHub MLflow tracking
dagshub.init(
    repo_owner="vasukrishna001",  # Your DagsHub username
    repo_name="sp25_taxi",  # Your repository name
    mlflow=True  # Enable MLflow tracking
)
# Set MLflow tracking URI to your DagsHub repo
mlflow.set_tracking_uri("https://dagshub.com/vasukrishna001/sp25_taxi.mlflow")
# Connections verified
print("MLflow Tracking URI:", mlflow.get_tracking_uri())
# Out:
# Accessing as vasukrishna001
# Initialized MLflow to track repo "vasukrishna001/sp25_taxi"
# Repository vasukrishna001/sp25_taxi initialized!
# MLflow Tracking URI: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow

# %%
from src.experiment_utils import set_mlflow_tracking, log_model_to_mlflow
from dotenv import load_dotenv
import os
load_dotenv() 

mlflow = set_mlflow_tracking()
log_model_to_mlflow(model, X_test_only_numeric, "LGBMRegressor", "mean_absolute_error", score=test_mae)
# Out:
# INFO:src.experiment_utils:MLflow tracking URI and credentials set.
# INFO:src.experiment_utils:Experiment set to: LGBMRegressor
# INFO:src.experiment_utils:Logged mean_absolute_error: 3.3054128762542527
# C:\Users\vasub\anaconda3\envs\sp25_taxi_ipt\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# INFO:src.experiment_utils:Model signature inferred.
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025/03/03 21:09:04 INFO mlflow.models.model: Found the following environment variables used during model inference: [HOPSWORKS_API_KEY]. Please check if you need to set them when deploying the model. To disable this message, set environment variable `MLFLOW_RECORD_ENV_VARS_IN_MODEL_LOGGING` to `false`.
# Registered model 'LGBMRegressor' already exists. Creating a new version of this model...
# 2025/03/03 21:13:06 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: LGBMRegressor, version 9
# Created version '9' of model 'LGBMRegressor'.
# INFO:src.experiment_utils:Model logged with name: LGBMRegressor
# 🏃 View run peaceful-doe-228 at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/4/runs/290066e7a4274668b7187605f2483e82
# 🧪 View experiment at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/4

# %% [markdown]
# Tuning Learning Rate

# %%
import lightgbm as lgb
import mlflow
import mlflow.sklearn
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV

# Initialize MLflow experiment
mlflow.set_experiment("LightGBM_Tuning")

# Define learning rate values to test
learning_rates = [0.01, 0.05, 0.1, 0.2, 0.5]
best_lr = None
best_mae = float("inf")

print("Step 1: Tuning Learning Rate...")
for lr in learning_rates:
    with mlflow.start_run():
        model = lgb.LGBMRegressor(learning_rate=lr)
        model.fit(X_train_only_numeric, y_train)
        y_pred = model.predict(X_test_only_numeric)
        mae = mean_absolute_error(y_test, y_pred)

        # Log results to MLflow
        mlflow.log_param("learning_rate", lr)
        mlflow.log_metric("mae", mae)

        print(f"Learning Rate: {lr}, MAE: {mae}")

        # Store the best learning rate
        if mae < best_mae:
            best_mae = mae
            best_lr = lr

print(f"Best Learning Rate: {best_lr} with MAE: {best_mae}")
# Out:
# Step 1: Tuning Learning Rate...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.181975 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 159651
# [LightGBM] [Info] Number of data points in the train set: 55900, number of used features: 672
# [LightGBM] [Info] Start training from score 11.110286
# Learning Rate: 0.01, MAE: 7.971859486998356
# 🏃 View run sneaky-conch-887 at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6/runs/e7825325904340549dd55de9526de386
# 🧪 View experiment at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.093417 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 159651
# [LightGBM] [Info] Number of data points in the train set: 55900, number of used features: 672
# [LightGBM] [Info] Start training from score 11.110286
# Learning Rate: 0.05, MAE: 3.386197397898954
# 🏃 View run handsome-elk-187 at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6/runs/af9f8acb025d43ed9bc4be9cc585ff44
# 🧪 View experiment at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.166605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 159651
# [LightGBM] [Info] Number of data points in the train set: 55900, number of used features: 672
# [LightGBM] [Info] Start training from score 11.110286
# Learning Rate: 0.1, MAE: 3.3054128762542527
# 🏃 View run stylish-tern-659 at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6/runs/19957e975a3a4dffb9fd8e0184d82ebf
# 🧪 View experiment at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.092802 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 159651
# [LightGBM] [Info] Number of data points in the train set: 55900, number of used features: 672
# [LightGBM] [Info] Start training from score 11.110286
# Learning Rate: 0.2, MAE: 3.3631658936488766
# 🏃 View run trusting-mouse-63 at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6/runs/2f3cdbf7eb264ab88b2db8126e26e99a
# 🧪 View experiment at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.171016 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 159651
# [LightGBM] [Info] Number of data points in the train set: 55900, number of used features: 672
# [LightGBM] [Info] Start training from score 11.110286
# Learning Rate: 0.5, MAE: 3.5185087916559756
# 🏃 View run abrasive-sow-177 at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6/runs/c59d60bc31974299bab4e753f72cc00a
# 🧪 View experiment at: https://dagshub.com/vasukrishna001/sp25_taxi.mlflow/#/experiments/6
# Best Learning Rate: 0.1 with MAE: 3.3054128762542527

# %% [markdown]
# Hyperparameter TUNING USING BEST LEARNING RATE

# %%
import lightgbm as lgb
import mlflow
import mlflow.sklearn
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
import pandas as pd

print("Step 2: Tuning Other Hyperparameters...")
param_distributions = {
    "num_leaves": [10, 20, 40],
    "max_depth": [5, 10, 15],
    "min_child_samples": [2, 5, 10],
    "feature_fraction": [0.6, 0.8],
    "reg_lambda": [0, 0.1, 0.5]
}

model = lgb.LGBMRegressor(learning_rate=best_lr)

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distributions,
    n_iter=10,  # Number of combinations to test
    scoring="neg_mean_absolute_error",
    cv=3,
    verbose=2,
    random_state=42,
)

random_search.fit(X_train_only_numeric, y_train)

# Get best parameters and evaluate
best_params = random_search.best_params_
best_model = random_search.best_estimator_
y_pred_final = best_model.predict(X_test_only_numeric)
final_mae = mean_absolute_error(y_test, y_pred_final)

print(f"Final Model MAE: {final_mae}")

# Convert integer columns to float before logging in MLflow
input_example = pd.DataFrame(X_test_only_numeric.iloc[:1]).astype("float64")

# Log final results in MLflow with corrected schema
with mlflow.start_run():
    mlflow.log_params(best_params)
    mlflow.log_metric("final_mae", final_mae)
    mlflow.sklearn.log_model(best_model, "best_lightgbm_model", input_example=input_example)
# Out:
# Step 2: Tuning Other Hyperparameters...
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.170076 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=15, min_child_samples=10, num_leaves=20, reg_lambda=0.5; total time=   3.9s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=15, min_child_samples=10, num_leaves=20, reg_lambda=0.5; total time=   3.6s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.118577 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=15, min_child_samples=10, num_leaves=20, reg_lambda=0.5; total time=   3.6s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.116694 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=10, min_child_samples=2, num_leaves=10, reg_lambda=0.1; total time=   2.9s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.115791 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=10, min_child_samples=2, num_leaves=10, reg_lambda=0.1; total time=   2.9s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.115008 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=10, min_child_samples=2, num_leaves=10, reg_lambda=0.1; total time=   2.9s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.120348 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=10, min_child_samples=10, num_leaves=20, reg_lambda=0.5; total time=   3.6s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.077753 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=10, min_child_samples=10, num_leaves=20, reg_lambda=0.5; total time=   3.7s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.115647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=10, min_child_samples=10, num_leaves=20, reg_lambda=0.5; total time=   4.1s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.113170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=15, min_child_samples=2, num_leaves=10, reg_lambda=0.1; total time=   3.6s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.184430 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=15, min_child_samples=2, num_leaves=10, reg_lambda=0.1; total time=   4.0s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.134926 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=15, min_child_samples=2, num_leaves=10, reg_lambda=0.1; total time=   3.5s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.151179 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=5, num_leaves=20, reg_lambda=0.1; total time=   3.7s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125297 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=5, num_leaves=20, reg_lambda=0.1; total time=   3.7s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.136391 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=5, num_leaves=20, reg_lambda=0.1; total time=   3.6s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.160143 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=10, min_child_samples=2, num_leaves=10, reg_lambda=0.5; total time=   3.6s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.133606 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=10, min_child_samples=2, num_leaves=10, reg_lambda=0.5; total time=   3.7s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.131304 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=10, min_child_samples=2, num_leaves=10, reg_lambda=0.5; total time=   3.5s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.139688 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=10, num_leaves=10, reg_lambda=0.5; total time=   3.3s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.130523 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=10, num_leaves=10, reg_lambda=0.5; total time=   3.2s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.140391 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=10, num_leaves=10, reg_lambda=0.5; total time=   3.2s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.142994 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=10, min_child_samples=10, num_leaves=40, reg_lambda=0; total time=   5.3s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.136451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153158
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 8.169855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=10, min_child_samples=10, num_leaves=40, reg_lambda=0; total time=   5.3s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.138484 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154957
# [LightGBM] [Info] Number of data points in the train set: 37267, number of used features: 672
# [LightGBM] [Info] Start training from score 11.678268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV] END feature_fraction=0.6, max_depth=10, min_child_samples=10, num_leaves=40, reg_lambda=0; total time=   5.2s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122372 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156461
# [LightGBM] [Info] Number of data points in the train set: 37266, number of used features: 672
# [LightGBM] [Info] Start training from score 13.482799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [CV] END feature_fraction=0.8, max_depth=5, min_child_samples=10, num_leaves=10, reg_lambda=0.1; total time=   3.1s
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8

# %%
print(f"{final_mae:.4f}")
